// %% [markdown]
// <h1 style="color:DodgerBlue">Простое наследование</h1>

// %% [markdown]
// Простое наследование в C# позволяет создавать новые классы на основе существующих, наследуя их свойства и методы. Это мощный механизм для повторного использования кода и организации программ на основе иерархии классов. Давайте рассмотрим пример наследования с классами `Vehicle`, `Car` и `Motorcycle`.
//
// ### Шаг 1: Определение базового класса
//
// Сначала определим базовый класс `Vehicle`. Этот класс будет содержать общие свойства и методы, которые могут быть у всех транспортных средств.
//
// ```csharp
// public class Vehicle
// {
//     // Свойство для хранения марки транспортного средства
//     public string Make { get; set; }
//
//     // Свойство для хранения модели транспортного средства
//     public string Model { get; set; }
//
//     // Конструктор класса Vehicle
//     public Vehicle(string make, string model)
//     {
//         Make = make;
//         Model = model;
//     }
//
//     // Метод для отображения информации о транспортном средстве
//     public void DisplayInfo()
//     {
//         Console.WriteLine($"Производитель: {Make}, Модель: {Model}");
//     }
// }
// ```
//
// ### Шаг 2: Создание производных классов
//
// Теперь создадим два производных класса `Car` и `Motorcycle`, которые наследуют от базового класса `Vehicle`.
//
// #### Класс Car
//
// Класс `Car` добавит дополнительные свойства, специфичные для автомобилей, например, количество дверей.
//
// ```csharp
// public class Car : Vehicle
// {
//     // Свойство для хранения количества дверей
//     public int Doors { get; set; }
//
//     // Конструктор класса Car
//     public Car(string make, string model, int doors) : base(make, model)
//     {
//         Doors = doors;
//     }
//
//     // Переопределенный метод DisplayInfo для отображения информации о автомобиле
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Двери: {Doors}");
//     }
// }
// ```
//
// #### Класс Motorcycle
//
// Аналогично, класс `Motorcycle` может добавить свои специфические свойства, например, тип двигателя.
//
// ```csharp
// public class Motorcycle : Vehicle
// {
//     // Свойство для хранения типа двигателя
//     public string EngineType { get; set; }
//
//     // Конструктор класса Motorcycle
//     public Motorcycle(string make, string model, string engineType) : base(make, model)
//     {
//         EngineType = engineType;
//     }
//
//     // Переопределенный метод DisplayInfo для отображения информации о мотоцикле
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Вид двигателя: {EngineType}");
//     }
// }
// ```
//
// ### Шаг 3: Использование классов
//
// Теперь мы можем создать экземпляры наших классов и использовать их.
//
// ```csharp
// // Создаем объект класса Car
// Car myCar = new Car("Toyota", "Corolla", 4);
// myCar.DisplayInfo(); // Выводит информацию о автомобиле
//
// // Создаем объект класса Motorcycle
// Motorcycle myMotorcycle = new Motorcycle("Honda", "CBR600RR", "Inline Four");
// myMotorcycle.DisplayInfo(); // Выводит информацию о мотоцикле
//
//
// ```
//
// ### Объяснение кода
//
// - **Базовый класс `Vehicle`**: Определяет общую структуру для всех транспортных средств, включая свойства `Make` и `Model`, а также метод `DisplayInfo()` для вывода информации.
// - **Производные классы `Car` и `Motorcycle`**: Наследуют от `Vehicle` и добавляют собственные свойства (`Doors` для `Car` и `EngineType` для `Motorcycle`). Также переопределяют метод `DisplayInfo()` для вывода дополнительной информации.
// - **Использование классов**: В `Main` создаются экземпляры `Car` и `Motorcycle`, и вызывается метод `DisplayInfo()` для каждого из них, демонстрируя различие в информации, которую они выводят.
//
// Этот пример показывает, как можно использовать простое наследование в C# для создания иерархии классов, где каждый класс расширяет функциональность предка, сохраняя при этом возможность индивидуализации своих свойств и поведения.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Vehicle, Car и Motorcycle ниже в блоке:</h4>
//
// ----

// %%
using System;

// ==================== Базовый класс Vehicle ====================
public class Vehicle
{
    // Свойство для хранения марки транспортного средства
    public string Make { get; set; }

    // Свойство для хранения модели транспортного средства
    public string Model { get; set; }

    // Конструктор класса Vehicle
    public Vehicle(string make, string model)
    {
        Make = make;
        Model = model;
    }

    // Метод для отображения информации о транспортном средстве
    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Производитель: {Make}, Модель: {Model}");
    }
}

// ==================== Производный класс Car ====================
public class Car : Vehicle
{
    // Свойство для хранения количества дверей
    public int Doors { get; set; }

    // Конструктор класса Car
    public Car(string make, string model, int doors) : base(make, model)
    {
        Doors = doors;
    }

    // Переопределённый метод DisplayInfo
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Двери: {Doors}");
    }
}

// ==================== Производный класс Motorcycle ====================
public class Motorcycle : Vehicle
{
    // Свойство для хранения типа двигателя
    public string EngineType { get; set; }

    // Конструктор класса Motorcycle
    public Motorcycle(string make, string model, string engineType) : base(make, model)
    {
        EngineType = engineType;
    }

    // Переопределённый метод DisplayInfo
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Вид двигателя: {EngineType}");
    }
}

// ==================== Демонстрация (top-level код) ====================

Console.WriteLine("=== Создание объектов ===\n");

// Создаём объект класса Car
Car myCar = new Car("Toyota", "Corolla", 4);
myCar.DisplayInfo();

Console.WriteLine();

// Создаём объект класса Motorcycle
Motorcycle myMotorcycle = new Motorcycle("Honda", "CBR600RR", "Inline Four");
myMotorcycle.DisplayInfo();

Console.WriteLine("\n=== Полиморфизм через базовый тип ===\n");

Vehicle[] vehicles = { myCar, myMotorcycle };
foreach (Vehicle v in vehicles)
{
    v.DisplayInfo();
    Console.WriteLine();
}
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-13308.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://192.168.0.13:2053/", "http://127.0.0.1:2053/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '13308.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>
// === Создание объектов ===
//
// Производитель: Toyota, Модель: Corolla
// Двери: 4
//
// Производитель: Honda, Модель: CBR600RR
// Вид двигателя: Inline Four
//
// === Полиморфизм через базовый тип ===
//
// Производитель: Toyota, Модель: Corolla
// Двери: 4
//
// Производитель: Honda, Модель: CBR600RR
// Вид двигателя: Inline Four

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также простое наследование.

// %%
using System;

// ==================== Базовый класс Animal ====================
public class Animal
{
    // -------- Приватные поля --------
    private string _name;
    private int _age;
    private double _weight;

    // -------- Свойство Name (get/set с валидацией) --------
    public string Name
    {
        get { return _name; }
        set
        {
            if (string.IsNullOrWhiteSpace(value))
                throw new ArgumentException("Имя не может быть пустым!");
            _name = value;
        }
    }

    // -------- Свойство Age (get/set с валидацией) --------
    public int Age
    {
        get { return _age; }
        set
        {
            if (value < 0)
                throw new ArgumentOutOfRangeException("Возраст не может быть отрицательным!");
            _age = value;
        }
    }

    // -------- Свойство Weight (get/set с валидацией) --------
    public double Weight
    {
        get { return _weight; }
        set
        {
            if (value <= 0)
                throw new ArgumentOutOfRangeException("Вес должен быть положительным!");
            _weight = value;
        }
    }

    // -------- Статический атрибут --------
    public static int TotalAnimals { get; private set; } = 0;

    // ==================== Конструкторы ====================
    public Animal()
    {
        TotalAnimals++;
        _name = "Безымянное";
        _age = 0;
        _weight = 1.0;
        Console.WriteLine($"[Animal] Создано по умолчанию. Всего: {TotalAnimals}");
    }

    public Animal(string name, int age, double weight) : this()
    {
        Name = name;
        Age = age;
        Weight = weight;
        Console.WriteLine($"[Animal] Создано: {Name}, {Age} лет, {Weight} кг");
    }

    // ==================== Обычные методы ====================
    // virtual — чтобы наследники могли переопределить
    public virtual void MakeSound()
    {
        Console.WriteLine($"[Animal] {Name} издаёт неопределённый звук.");
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"[Animal] Имя: {Name}, Возраст: {Age}, Вес: {Weight:F2}");
    }

    public void Eat(double amount)
    {
        if (amount <= 0)
        {
            Console.WriteLine("[Animal] Некорректное количество еды.");
            return;
        }
        Weight += amount * 0.1;
        Console.WriteLine($"[Animal] {Name} поел. Новый вес: {Weight:F2} кг");
    }

    // ==================== Статический метод ====================
    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"[Animal] Общее количество животных: {TotalAnimals}");
    }
}

// ==================== Производный класс Dog ====================
public class Dog : Animal
{
    private string _breed;

    // Свойство Breed с геттером и сеттером
    public string Breed
    {
        get { return _breed; }
        set
        {
            if (string.IsNullOrWhiteSpace(value))
                throw new ArgumentException("Порода не может быть пустой!");
            _breed = value;
        }
    }

    // Конструктор по умолчанию
    public Dog() : base()
    {
        _breed = "Дворняга";
        Console.WriteLine("[Dog] Создана собака по умолчанию.");
    }

    // Параметризованный конструктор
    public Dog(string name, int age, double weight, string breed)
        : base(name, age, weight)
    {
        Breed = breed;
        Console.WriteLine($"[Dog] Создана собака: {Name}, порода: {Breed}");
    }

    // Переопределение метода (полиморфизм)
    public override void MakeSound()
    {
        Console.WriteLine($"[Dog] {Name} говорит: Гав-гав!");
    }

    // Переопределение DisplayInfo с вызовом base
    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"[Dog] Порода: {Breed}");
    }

    // Собственный метод Dog
    public void BringSlippers()
    {
        Console.WriteLine($"[Dog] {Name} принёс тапочки!");
    }
}

// ==================== Производный класс Cat ====================
public class Cat : Animal
{
    private bool _isIndoor;

    // Свойство IsIndoor с геттером и сеттером
    public bool IsIndoor
    {
        get { return _isIndoor; }
        set { _isIndoor = value; }
    }

    public Cat() : base()
    {
        _isIndoor = true;
        Console.WriteLine("[Cat] Создан кот по умолчанию.");
    }

    public Cat(string name, int age, double weight, bool isIndoor)
        : base(name, age, weight)
    {
        IsIndoor = isIndoor;
        Console.WriteLine($"[Cat] Создан кот: {Name}, домашний: {IsIndoor}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"[Cat] {Name} говорит: Мяу!");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"[Cat] Домашний: {IsIndoor}");
    }

    // Собственный метод Cat
    public void Purr()
    {
        Console.WriteLine($"[Cat] {Name} мурлычет...");
    }
}

// ==================== Производный класс Bird ====================
public class Bird : Animal
{
    private double _wingspan;
    private bool _canFly;

    // Свойство Wingspan с геттером и сеттером
    public double Wingspan
    {
        get { return _wingspan; }
        set
        {
            if (value <= 0)
                throw new ArgumentOutOfRangeException("Размах крыльев должен быть положительным!");
            _wingspan = value;
        }
    }

    // Свойство CanFly с геттером и сеттером
    public bool CanFly
    {
        get { return _canFly; }
        set { _canFly = value; }
    }

    public Bird() : base()
    {
        _wingspan = 20.0;
        _canFly = true;
        Console.WriteLine("[Bird] Создана птица по умолчанию.");
    }

    public Bird(string name, int age, double weight, double wingspan, bool canFly)
        : base(name, age, weight)
    {
        Wingspan = wingspan;
        CanFly = canFly;
        Console.WriteLine($"[Bird] Создана птица: {Name}, размах крыльев: {Wingspan} см");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"[Bird] {Name} поёт: Чик-чирик!");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"[Bird] Размах крыльев: {Wingspan} см, Умеет летать: {CanFly}");
    }

    // Собственный метод Bird
    public void Fly()
    {
        if (CanFly)
            Console.WriteLine($"[Bird] {Name} летает!");
        else
            Console.WriteLine($"[Bird] {Name} не умеет летать.");
    }
}

// ==================== Производный класс Fish ====================
public class Fish : Animal
{
    private string _waterType;
    private int _maxDepth;

    // Свойство WaterType с геттером и сеттером
    public string WaterType
    {
        get { return _waterType; }
        set
        {
            if (string.IsNullOrWhiteSpace(value))
                throw new ArgumentException("Тип воды не может быть пустым!");
            _waterType = value;
        }
    }

    // Свойство MaxDepth с геттером и сеттером
    public int MaxDepth
    {
        get { return _maxDepth; }
        set
        {
            if (value <= 0)
                throw new ArgumentOutOfRangeException("Глубина должна быть положительной!");
            _maxDepth = value;
        }
    }

    public Fish() : base()
    {
        _waterType = "Пресная";
        _maxDepth = 10;
        Console.WriteLine("[Fish] Создана рыба по умолчанию.");
    }

    public Fish(string name, int age, double weight, string waterType, int maxDepth)
        : base(name, age, weight)
    {
        WaterType = waterType;
        MaxDepth = maxDepth;
        Console.WriteLine($"[Fish] Создана рыба: {Name}, вода: {WaterType}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"[Fish] {Name} молчит (рыбы не издают звуков).");
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"[Fish] Тип воды: {WaterType}, Макс. глубина: {MaxDepth} м");
    }

    // Собственный метод Fish
    public void Swim()
    {
        Console.WriteLine($"[Fish] {Name} плавает на глубине до {MaxDepth} м.");
    }
}

// ==================== Демонстрация (top-level код) ====================

Console.WriteLine("=== Создание экземпляров классов ===\n");

Dog dog = new Dog("Рекс", 5, 25.0, "Лабрадор");
Cat cat = new Cat("Мурка", 2, 4.2, true);
Bird bird = new Bird("Кеша", 1, 0.4, 30.0, true);
Fish fish = new Fish("Немо", 1, 0.2, "Морская", 50);

Console.WriteLine("\n=== Простое наследование: DisplayInfo ===\n");

dog.DisplayInfo();
Console.WriteLine();
cat.DisplayInfo();
Console.WriteLine();
bird.DisplayInfo();
Console.WriteLine();
fish.DisplayInfo();

Console.WriteLine("\n=== Полиморфизм через базовый тип ===\n");

Animal[] animals = { dog, cat, bird, fish };
foreach (Animal a in animals)
{
    a.MakeSound();
}

Console.WriteLine("\n=== Собственные методы производных классов ===\n");

dog.BringSlippers();
cat.Purr();
bird.Fly();
fish.Swim();

Console.WriteLine("\n=== Свойства и состояние ===\n");

Console.WriteLine($"dog.Breed = {dog.Breed}");
Console.WriteLine($"cat.IsIndoor = {cat.IsIndoor}");
Console.WriteLine($"bird.Wingspan = {bird.Wingspan}, CanFly = {bird.CanFly}");
Console.WriteLine($"fish.WaterType = {fish.WaterType}, MaxDepth = {fish.MaxDepth}");

Console.WriteLine("\n=== Изменение свойств через сеттеры ===\n");

dog.Breed = "Овчарка";
cat.IsIndoor = false;
bird.CanFly = false;
fish.MaxDepth = 100;

Console.WriteLine($"dog.Breed = {dog.Breed}");
Console.WriteLine($"cat.IsIndoor = {cat.IsIndoor}");
Console.WriteLine($"bird.CanFly = {bird.CanFly}");
Console.WriteLine($"fish.MaxDepth = {fish.MaxDepth}");

Console.WriteLine("\n=== Проверка валидации сеттеров ===\n");

try { dog.Name = ""; }
catch (ArgumentException ex) { Console.WriteLine($"Ошибка: {ex.Message}"); }

try { cat.Age = -1; }
catch (ArgumentOutOfRangeException ex) { Console.WriteLine($"Ошибка: {ex.Message}"); }

try { bird.Wingspan = 0; }
catch (ArgumentOutOfRangeException ex) { Console.WriteLine($"Ошибка: {ex.Message}"); }

try { fish.WaterType = ""; }
catch (ArgumentException ex) { Console.WriteLine($"Ошибка: {ex.Message}"); }

Console.WriteLine("\n=== Статические члены ===\n");

Animal.DisplayTotalAnimals();
Console.WriteLine($"TotalAnimals (через свойство): {Animal.TotalAnimals}");
// Out:
// === Создание экземпляров классов ===
//
// [Animal] Создано по умолчанию. Всего: 1
// [Animal] Создано: Рекс, 5 лет, 25 кг
// [Dog] Создана собака: Рекс, порода: Лабрадор
// [Animal] Создано по умолчанию. Всего: 2
// [Animal] Создано: Мурка, 2 лет, 4,2 кг
// [Cat] Создан кот: Мурка, домашний: True
// [Animal] Создано по умолчанию. Всего: 3
// [Animal] Создано: Кеша, 1 лет, 0,4 кг
// [Bird] Создана птица: Кеша, размах крыльев: 30 см
// [Animal] Создано по умолчанию. Всего: 4
// [Animal] Создано: Немо, 1 лет, 0,2 кг
// [Fish] Создана рыба: Немо, вода: Морская
//
// === Простое наследование: DisplayInfo ===
//
// [Animal] Имя: Рекс, Возраст: 5, Вес: 25,00
// [Dog] Порода: Лабрадор
//
// [Animal] Имя: Мурка, Возраст: 2, Вес: 4,20
// [Cat] Домашний: True
//
// [Animal] Имя: Кеша, Возраст: 1, Вес: 0,40
// [Bird] Размах крыльев: 30 см, Умеет летать: True
//
// [Animal] Имя: Немо, Возраст: 1, Вес: 0,20
// [Fish] Тип воды: Морская, Макс. глубина: 50 м
//
// === Полиморфизм через базовый тип ===
//
// [Dog] Рекс говорит: Гав-гав!
// [Cat] Мурка говорит: Мяу!
// [Bird] Кеша поёт: Чик-чирик!
// [Fish] Немо молчит (рыбы не издают звуков).
//
// === Собственные методы производных классов ===
//
// [Dog] Рекс принёс тапочки!
// [Cat] Мурка мурлычет...
// [Bird] Кеша летает!
// [Fish] Немо плавает на глубине до 50 м.
//
// === Свойства и состояние ===
//
// dog.Breed = Лабрадор
// cat.IsIndoor = True
// bird.Wingspan = 30, CanFly = True
// fish.WaterType = Морская, MaxDepth = 50
//
// === Изменение свойств через сеттеры ===
//
// dog.Breed = Овчарка
// cat.IsIndoor = False
// bird.CanFly = False
// fish.MaxDepth = 100
//
// === Проверка валидации сеттеров ===
//
// Ошибка: Имя не может быть пустым!
// Ошибка: Specified argument was out of the range of valid values. (Parameter 'Возраст не может быть отрицательным!')
// Ошибка: Specified argument was out of the range of valid values. (Parameter 'Размах крыльев должен быть положительным!')
// Ошибка: Тип воды не может быть пустым!
//
// === Статические члены ===
//
// [Animal] Общее количество животных: 4
// TotalAnimals (через свойство): 4
